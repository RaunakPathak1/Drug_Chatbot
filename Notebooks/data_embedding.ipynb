# %%
from sentence_transformers import SentenceTransformer
import numpy as np
import os
import glob

# %%
import chromadb
from chromadb.config import Settings

# %%
model = SentenceTransformer('all-MiniLM-L6-v2')

# %%
FOLDER_PATH = r"C:\Users\rauna\projects\llm_engineering\My Projects\Drug Chatbot\Synthetic_files"  
file_pattern = os.path.join(FOLDER_PATH, "*.txt")

# %%
print(file_pattern)
# Out:
# C:\Users\rauna\projects\llm_engineering\My Projects\Drug Chatbot\Synthetic_files\*.txt

# %%
file_paths = glob.glob(file_pattern)

# %%
print(file_paths)
# Out:
# ['C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\Synthetic_files\\file_01.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\Synthetic_files\\file_02.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\Synthetic_files\\file_03.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\Synthetic_files\\file_04.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\Synthetic_files\\file_05.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\Synthetic_files\\file_06.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\Synthetic_files\\file_07.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\Synthetic_files\\file_08.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\Synthetic_files\\file_09.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\Synthetic_files\\file_10.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\Synthetic_files\\file_11.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\Synthetic_files\\file_12.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\Synthetic_files\\file_13.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\Synthetic_files\\file_14.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\Synthetic_files\\file_15.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\Synthetic_files\\file_16.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\Synthetic_files\\file_17.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\Synthetic_files\\file_18.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\Synthetic_files\\file_19.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\Synthetic_files\\file_20.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\Synthetic_files\\file_21.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\Synthetic_files\\file_22.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\Synthetic_files\\file_23.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\Synthetic_files\\file_24.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\Synthetic_files\\file_25.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\Synthetic_files\\file_26.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\Synthetic_files\\file_27.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\Synthetic_files\\file_28.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\Synthetic_files\\file_29.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\Synthetic_files\\file_30.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\Synthetic_files\\file_31.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\Synthetic_files\\file_32.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\Synthetic_files\\file_33.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\Synthetic_files\\file_34.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\Synthetic_files\\file_35.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\Synthetic_files\\file_36.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\Synthetic_files\\file_37.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\Synthetic_files\\file_38.txt']

# %%
texts = []
filenames = []

# %%
for file_path in file_paths:
    try:
        with open(file_path, 'r', encoding='utf-8') as f:
            content = f.read().strip()
            if content:  # Only add non-empty files
                texts.append(content)
                filenames.append(os.path.basename(file_path))
                print(f"Loaded: {os.path.basename(file_path)}")
    except Exception as e:
        print(f"Error reading {file_path}: {e}")

# %%
for file_path in file_paths[1:2]:
    with open(file_path, 'r', encoding='utf-8') as f:
            content = f.read().strip()
            print(content)
            filenames.append(os.path.basename(file_path))
            print(f"Loaded: {os.path.basename(file_path)}")

# %%
embeddings = model.encode(texts)

# %%
display(embeddings)
# Out:
# array([[-0.03121755,  0.00714299, -0.01756535, ..., -0.01611793,
#         -0.01445116,  0.02758407],
#        [ 0.01701781, -0.06746283,  0.03736177, ...,  0.07838504,
#         -0.01671585,  0.02201158],
#        [-0.01052115, -0.02091547, -0.04784062, ...,  0.00063754,
#         -0.03845629, -0.00804244],
#        ...,
#        [-0.02444021,  0.03095116, -0.08432989, ...,  0.02079832,
#          0.00981694, -0.00664631],
#        [-0.0203063 ,  0.03741434, -0.05464162, ...,  0.02180241,
#         -0.00148364, -0.0752122 ],
#        [-0.00051512,  0.03226906, -0.0718165 , ...,  0.06185648,
#          0.01028941, -0.06245422]], shape=(38, 384), dtype=float32)

# %%
from IPython.display import display

# %%
display(len(texts[0]))
# Out:
# 2794

# %%
display(len(embeddings.tolist()))
# Out:
# 38

# %%
print(f"\n{'='*60}")
print(f"Model: all-MiniLM-L6-v2")
print(f"Embedding dimension: {embeddings.shape[1]}")
print(f"Number of files embedded: {embeddings.shape[0]}")
print(f"{'='*60}\n")
# Out:
# ============================================================
# Model: all-MiniLM-L6-v2
# Embedding dimension: 384
# Number of files embedded: 38
# ============================================================

# %%
for i, (filename, embedding) in enumerate(zip(filenames, embeddings)):
    print(f"File {i+1}: {filename}")
    print(f"Embedding shape: {embedding.shape}")
    print(f"First 10 values: {embedding[:10]}")
    print(f"Embedding norm: {np.linalg.norm(embedding):.4f}\n")

# %%
def cosine_similarity(vec1, vec2):
    return np.dot(vec1, vec2) / (np.linalg.norm(vec1) * np.linalg.norm(vec2))

# %%
print("Similarity Matrix:")
print("-" * 60)
for i in range(len(filenames)):
    for j in range(len(filenames)):
        sim = cosine_similarity(embeddings[i], embeddings[j])
        print(f"{filenames[i]} vs {filenames[j]}: {sim:.4f}")
    print()

# %%
COLLECTION_NAME = "document_embeddings"  # ChromaDB collection name
DB_PATH = r"C:\Users\rauna\projects\llm_engineering\My Projects\Drug Chatbot\ChromaDB\chroma_db"

# %%
chroma_client = chromadb.PersistentClient(path=DB_PATH)

# %%
collection = chroma_client.get_or_create_collection(
    name=COLLECTION_NAME,
    metadata={"description": "Text file embeddings using all-MiniLM-L6-v2"}
)

# %%
print(collection)
# Out:
# Collection(name=document_embeddings)

# %%
print("Adding embeddings to ChromaDB...")
ids = [f"doc_{i}" for i in range(len(filenames))]
metadatas = [{"filename": fn, "file_path": fp} for fn, fp in zip(filenames, file_paths)]
# Out:
# Adding embeddings to ChromaDB...

# %%
print(ids)
# Out:
# ['doc_0', 'doc_1', 'doc_2', 'doc_3', 'doc_4', 'doc_5', 'doc_6', 'doc_7', 'doc_8', 'doc_9', 'doc_10', 'doc_11', 'doc_12', 'doc_13', 'doc_14', 'doc_15', 'doc_16', 'doc_17', 'doc_18', 'doc_19', 'doc_20', 'doc_21', 'doc_22', 'doc_23', 'doc_24', 'doc_25', 'doc_26', 'doc_27', 'doc_28', 'doc_29', 'doc_30', 'doc_31', 'doc_32', 'doc_33', 'doc_34', 'doc_35', 'doc_36', 'doc_37']

# %%
print(metadatas)
# Out:
# [{'filename': 'file_01.txt', 'file_path': 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\Synthetic_files\\file_01.txt'}, {'filename': 'file_02.txt', 'file_path': 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\Synthetic_files\\file_02.txt'}, {'filename': 'file_03.txt', 'file_path': 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\Synthetic_files\\file_03.txt'}, {'filename': 'file_04.txt', 'file_path': 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\Synthetic_files\\file_04.txt'}, {'filename': 'file_05.txt', 'file_path': 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\Synthetic_files\\file_05.txt'}, {'filename': 'file_06.txt', 'file_path': 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\Synthetic_files\\file_06.txt'}, {'filename': 'file_07.txt', 'file_path': 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\Synthetic_files\\file_07.txt'}, {'filename': 'file_08.txt', 'file_path': 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\Synthetic_files\\file_08.txt'}, {'filename': 'file_09.txt', 'file_path': 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\Synthetic_files\\file_09.txt'}, {'filename': 'file_10.txt', 'file_path': 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\Synthetic_files\\file_10.txt'}, {'filename': 'file_11.txt', 'file_path': 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\Synthetic_files\\file_11.txt'}, {'filename': 'file_12.txt', 'file_path': 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\Synthetic_files\\file_12.txt'}, {'filename': 'file_13.txt', 'file_path': 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\Synthetic_files\\file_13.txt'}, {'filename': 'file_14.txt', 'file_path': 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\Synthetic_files\\file_14.txt'}, {'filename': 'file_15.txt', 'file_path': 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\Synthetic_files\\file_15.txt'}, {'filename': 'file_16.txt', 'file_path': 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\Synthetic_files\\file_16.txt'}, {'filename': 'file_17.txt', 'file_path': 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\Synthetic_files\\file_17.txt'}, {'filename': 'file_18.txt', 'file_path': 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\Synthetic_files\\file_18.txt'}, {'filename': 'file_19.txt', 'file_path': 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\Synthetic_files\\file_19.txt'}, {'filename': 'file_20.txt', 'file_path': 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\Synthetic_files\\file_20.txt'}, {'filename': 'file_21.txt', 'file_path': 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\Synthetic_files\\file_21.txt'}, {'filename': 'file_22.txt', 'file_path': 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\Synthetic_files\\file_22.txt'}, {'filename': 'file_23.txt', 'file_path': 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\Synthetic_files\\file_23.txt'}, {'filename': 'file_24.txt', 'file_path': 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\Synthetic_files\\file_24.txt'}, {'filename': 'file_25.txt', 'file_path': 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\Synthetic_files\\file_25.txt'}, {'filename': 'file_26.txt', 'file_path': 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\Synthetic_files\\file_26.txt'}, {'filename': 'file_27.txt', 'file_path': 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\Synthetic_files\\file_27.txt'}, {'filename': 'file_28.txt', 'file_path': 'C:\\Users\\raun ...

# %%
collection.add(
    embeddings=embeddings.tolist(),
    documents=texts,
    metadatas=metadatas,
    ids=ids
)

# %%
display(embeddings.tolist()[0])
display(texts[0])
display(metadatas[0])
display(ids[0])
# Out:
# [-0.0312175489962101,
#  0.007142986170947552,
#  -0.017565354704856873,
#  -0.014416318386793137,
#  -0.06413102149963379,
#  0.009872017428278923,
#  0.07674046605825424,
#  0.05445420742034912,
#  -0.07276026904582977,
#  -0.01634938456118107,
#  -0.0555085688829422,
#  -0.08762987703084946,
#  -0.0006610637065023184,
#  0.0247679241001606,
#  0.05791550874710083,
#  -0.0040714251808822155,
#  0.0435117706656456,
#  -0.017558185383677483,
#  0.015233439393341541,
#  0.0625896155834198,
#  0.030219666659832,
#  0.051577627658843994,
#  0.015342476777732372,
rather possesses a comfortable robustness, suggesting a life of practical activity rather than rigorous athletic pursuit. His posture is generally upright, conveying a sense of quiet confidence and attentiveness.\n\n**His face is perhaps his most memorable canvas.** A strong jawline anchors a face that’s often framed by a neatly trimmed, dark beard, flecked with hints of distinguished grey that add a touch of maturity. His hair, too, is dark, often kept short and practical, with a subtle recession at the temples that only serves to highlight the intelligence in his eyes.\n\n**And it’s his eyes that truly hold your gaze.** They are a deep, thoughtful brown, often described as possessing a warm, knowing glint. They are expressive eyes, capable of conveying a wealth of emotion without a single word – from a gentle amusement to a deep empathy. When he’s listening, they’re intensely focused; when he’s speaking, they sparkle with earnestness.\n\n**Distinctive Features:**\n\n*   **The Subtle Scar:** A faint, almost imperceptible scar graces his left eyebrow, a subtle testament to a forgotten childhood mishap or a moment of unexpected adventure. It’s not a mark of aggression, but rather a tiny story etched onto his skin.\n*   **The Steady Hands:** Paracetamol’s hands are often noted for their steadiness. They are strong, capable hands, with well-maintained nails. Whether he's gesturing in conversation, holding a tool, or simply resting them, there’s an inherent calm and control about them.\n*   **The Faint Aroma of Comfort:** It’s not a cologne, but rather a subtle, almost imperceptible scent that seems to cling to him – a faint, clean aroma that evokes a sense of calm and well-being. It’s the olfactory equivalent of his reassuring presence.\n*   **The Gentle Smile:** When Paracetamol smiles, it’s a genuine, unhurried affair. It starts in his eyes and blossoms across his face, crinkling the corners of his eyes and revealing a warmth that instantly puts others at ease. It’s a smile that speaks of kindness and a quiet understanding.\n\nIn essence, Paracetamol presents a picture of quiet strength and approachable wisdom. He’s a man whose physical appearance is as comforting and reliable as the name he carries, someone you feel you can trust and confide in."
# {'filename': 'file_01.txt',
#  'file_path': 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\Synthetic_files\\file_01.txt'}
# 'doc_0'

# %%
query = "who is insulin"

# %%
results = collection.query(
    query_texts=[query],
    n_results=min(5, len(filenames))
)

# %%
print("\nMost similar documents:")
for i, (doc_id, distance, metadata) in enumerate(zip(
    results['ids'][0], 
    results['distances'][0], 
    results['metadatas'][0]
)):
    similarity = 1 - distance  # Convert distance to similarity
    print(f"  {i+1}. {metadata['filename']} (similarity: {similarity:.4f})")
# Out:
# Most similar documents:
#   1. file_23.txt (similarity: 0.2574)
#   2. file_26.txt (similarity: 0.2344)
#   3. file_20.txt (similarity: 0.1864)
#   4. file_31.txt (similarity: 0.1614)
#   5. file_24.txt (similarity: 0.1581)

# %%
print("\n" + "="*60)
print("ChromaDB Collection Info:")
print("="*60)
print(f"Collection name: {COLLECTION_NAME}")
print(f"Total documents: {collection.count()}")
print(f"Database path: {DB_PATH}")
print("\nTo query this collection later, use:")
print(f"  collection = chroma_client.get_collection('{COLLECTION_NAME}')")
print(f"  results = collection.query(query_texts=['your query'], n_results=5)")
# Out:
# ============================================================
# ChromaDB Collection Info:
# ============================================================
# Collection name: document_embeddings
# Total documents: 38
# Database path: C:\Users\rauna\projects\llm_engineering\My Projects\Drug Chatbot\ChromaDB\chroma_db
#
# To query this collection later, use:
#   collection = chroma_client.get_collection('document_embeddings')
#   results = collection.query(query_texts=['your query'], n_results=5)
