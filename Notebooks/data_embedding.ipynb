# %%
from sentence_transformers import SentenceTransformer
import numpy as np
import os
import glob

# %%
import chromadb
from chromadb.config import Settings

# %%
model = SentenceTransformer('all-MiniLM-L6-v2')

# %%
FOLDER_PATH = r"C:\Users\rauna\projects\llm_engineering\My Projects\Drug Chatbot\archive_synthetic_files"  
file_pattern = os.path.join(FOLDER_PATH, "*.txt")

# %%
print(file_pattern)
# Out:
# C:\Users\rauna\projects\llm_engineering\My Projects\Drug Chatbot\archive_synthetic_files\*.txt

# %%
file_paths = glob.glob(file_pattern)
print(file_paths)
# Out:
# ['C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\archive_synthetic_files\\Insulin_file_20.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\archive_synthetic_files\\Insulin_file_21.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\archive_synthetic_files\\Insulin_file_22.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\archive_synthetic_files\\Insulin_file_23.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\archive_synthetic_files\\Insulin_file_24.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\archive_synthetic_files\\Insulin_file_25.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\archive_synthetic_files\\Insulin_file_26.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\archive_synthetic_files\\Insulin_file_27.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\archive_synthetic_files\\Insulin_file_28.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\archive_synthetic_files\\Insulin_file_29.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\archive_synthetic_files\\Insulin_file_30.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\archive_synthetic_files\\Insulin_file_31.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\archive_synthetic_files\\Insulin_file_32.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\archive_synthetic_files\\Insulin_file_33.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\archive_synthetic_files\\Insulin_file_34.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\archive_synthetic_files\\Insulin_file_35.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\archive_synthetic_files\\Insulin_file_36.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\archive_synthetic_files\\Insulin_file_37.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\archive_synthetic_files\\Insulin_file_38.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\archive_synthetic_files\\Paracetamol_file_01.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\archive_synthetic_files\\Paracetamol_file_02.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\archive_synthetic_files\\Paracetamol_file_03.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\archive_synthetic_files\\Paracetamol_file_04.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\archive_synthetic_files\\Paracetamol_file_05.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\archive_synthetic_files\\Paracetamol_file_06.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\archive_synthetic_files\\Paracetamol_file_07.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\archive_synthetic_files\\Paracetamol_file_08.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\archive_synthetic_files\\Paracetamol_file_09.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\archive_synthetic_files\\Paracetamol_file_10.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\archive_synthetic_files\\Paracetamol_file_11.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\archive_synthetic_files\\Paracetamol_file_12.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\archive_synthetic_files\\Paracetamol_file_13.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\archive_synthetic_files\\Paracetam ...

# %%
print(file_paths)
# Out:
# ['C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\archive_synthetic_files\\Insulin_file_20.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\archive_synthetic_files\\Insulin_file_21.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\archive_synthetic_files\\Insulin_file_22.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\archive_synthetic_files\\Insulin_file_23.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\archive_synthetic_files\\Insulin_file_24.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\archive_synthetic_files\\Insulin_file_25.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\archive_synthetic_files\\Insulin_file_26.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\archive_synthetic_files\\Insulin_file_27.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\archive_synthetic_files\\Insulin_file_28.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\archive_synthetic_files\\Insulin_file_29.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\archive_synthetic_files\\Insulin_file_30.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\archive_synthetic_files\\Insulin_file_31.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\archive_synthetic_files\\Insulin_file_32.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\archive_synthetic_files\\Insulin_file_33.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\archive_synthetic_files\\Insulin_file_34.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\archive_synthetic_files\\Insulin_file_35.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\archive_synthetic_files\\Insulin_file_36.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\archive_synthetic_files\\Insulin_file_37.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\archive_synthetic_files\\Insulin_file_38.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\archive_synthetic_files\\Paracetamol_file_01.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\archive_synthetic_files\\Paracetamol_file_02.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\archive_synthetic_files\\Paracetamol_file_03.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\archive_synthetic_files\\Paracetamol_file_04.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\archive_synthetic_files\\Paracetamol_file_05.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\archive_synthetic_files\\Paracetamol_file_06.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\archive_synthetic_files\\Paracetamol_file_07.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\archive_synthetic_files\\Paracetamol_file_08.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\archive_synthetic_files\\Paracetamol_file_09.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\archive_synthetic_files\\Paracetamol_file_10.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\archive_synthetic_files\\Paracetamol_file_11.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\archive_synthetic_files\\Paracetamol_file_12.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\archive_synthetic_files\\Paracetamol_file_13.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\archive_synthetic_files\\Paracetam ...

# %%
texts = []
filenames = []

# %%
for file_path in file_paths:
    try:
        with open(file_path, 'r', encoding='utf-8') as f:
            content = f.read().strip()
            if content:  # Only add non-empty files
                texts.append(content)
                filenames.append(os.path.basename(file_path))
                print(f"Loaded: {os.path.basename(file_path)}")
    except Exception as e:
        print(f"Error reading {file_path}: {e}")
# Out:
# Loaded: Insulin_file_20.txt
# Loaded: Insulin_file_21.txt
# Loaded: Insulin_file_22.txt
# Loaded: Insulin_file_23.txt
# Loaded: Insulin_file_24.txt
# Loaded: Insulin_file_25.txt
# Loaded: Insulin_file_26.txt
# Loaded: Insulin_file_27.txt
# Loaded: Insulin_file_28.txt
# Loaded: Insulin_file_29.txt
# Loaded: Insulin_file_30.txt
# Loaded: Insulin_file_31.txt
# Loaded: Insulin_file_32.txt
# Loaded: Insulin_file_33.txt
# Loaded: Insulin_file_34.txt
# Loaded: Insulin_file_35.txt
# Loaded: Insulin_file_36.txt
# Loaded: Insulin_file_37.txt
# Loaded: Insulin_file_38.txt
# Loaded: Paracetamol_file_01.txt
# Loaded: Paracetamol_file_02.txt
# Loaded: Paracetamol_file_03.txt
# Loaded: Paracetamol_file_04.txt
# Loaded: Paracetamol_file_05.txt
# Loaded: Paracetamol_file_06.txt
# Loaded: Paracetamol_file_07.txt
# Loaded: Paracetamol_file_08.txt
# Loaded: Paracetamol_file_09.txt
# Loaded: Paracetamol_file_10.txt
# Loaded: Paracetamol_file_11.txt
# Loaded: Paracetamol_file_12.txt
# Loaded: Paracetamol_file_13.txt
# Loaded: Paracetamol_file_14.txt
# Loaded: Paracetamol_file_15.txt
# Loaded: Paracetamol_file_16.txt
# Loaded: Paracetamol_file_17.txt
# Loaded: Paracetamol_file_18.txt
# Loaded: Paracetamol_file_19.txt

# %%
for file_path in file_paths[1:2]:
    with open(file_path, 'r', encoding='utf-8') as f:
            content = f.read().strip()
            print(content)
            filenames.append(os.path.basename(file_path))
            print(f"Loaded: {os.path.basename(file_path)}")
# Out:
# Topic: Personality traits and temperament
#
# Let's craft a vibrant tapestry of personality traits and temperament for our remarkable individual, Insulin!
#
# ## Insulin: A Symphony of Strengths and Sensibilities
#
# Insulin moves through the world with a captivating blend of **warmth, resilience, and a keen intellect**. She's not one to fade into the background; rather, she possesses an innate radiance that draws people in and makes them feel seen.
#
# **At her core, Insulin is profoundly empathetic.** She possesses a remarkable ability to tune into the emotions of others, not just intellectually, but with a deep, intuitive understanding. This makes her an exceptional listener, a trusted confidante, and someone who naturally fosters a sense of belonging. She often finds herself offering a comforting presence, a well-timed word of encouragement, or simply a silent, supportive shoulder.
#
# This empathy, however, is balanced by a **steadfast pragmatism.** Insulin isn't just about feeling; she's about doing. When faced with challenges, she approaches them with a clear head and a determined spirit. She's resourceful, innovative, and possesses a quiet strength that allows her to navigate complexities with grace. This isn't a loud, aggressive approach, but rather a persistent, thoughtful drive that ensures she tackles obstacles head-on.
#
# Insulin's temperament is characterized by a **gentle assertiveness.** She knows her worth and isn't afraid to voice her opinions or stand up for what she believes in. However, she does so with a diplomacy and consideration for others' feelings that disarms potential conflict. She can advocate for herself and for those she cares about without resorting to aggression, making her a powerful force for positive change.
#
# You'll often find Insulin exhibiting a **curious and analytical mind.** She's a natural learner, always seeking to understand the "why" behind things. This inquisitiveness fuels her growth and allows her to offer insightful perspectives. She enjoys dissecting problems, exploring different angles, and piecing together solutions. This intellectual spark is often accompanied by a **playful sense of humor**, which she uses to lighten the mood, connect with others, and add a touch of joy to everyday life.
#
# While generally even-tempered, Insulin also possesses a **deep well of passion.** When something ignites her interest or stirs her sense of justice, her enthusiasm becomes palpable. This passion is channeled into her endeavors, making her a dedicated and committed individual. She can be fiercely protective of those she loves and will go the extra mile to support their dreams and well-being.
#
# However, like all complex individuals, Insulin can also experience moments of **introspection and quiet reflection.** She values her inner world and takes time to process her experiences and emotions. This doesn't mean she's withdrawn, but rather that she honors the need for personal space and rejuvenation.
#
# In essence, Insulin is a woman of substance and spirit. She's a **beacon of kindness and understanding, a grounded problem-solver, and a vibrant individual** who brings a unique blend of warmth, intelligence, and unwavering strength to every aspect of her life. She's the kind of person who leaves a positive imprint on everyone she encounters, a testament to her beautifully balanced personality.
# Loaded: Insulin_file_21.txt

# %%
files = glob.glob(file_pattern, recursive=True)
print(files)
print(f"Found {len(files)} files in the knowledge base")

entire_knowledge_base = ""

for file_path in files:
    with open(file_path, 'r', encoding='utf-8') as f:
        entire_knowledge_base += f.read()
        entire_knowledge_base += "\n\n"

print(f"Total characters in knowledge base: {len(entire_knowledge_base):,}")
# Out:
# ['C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\archive_synthetic_files\\Insulin_file_20.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\archive_synthetic_files\\Insulin_file_21.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\archive_synthetic_files\\Insulin_file_22.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\archive_synthetic_files\\Insulin_file_23.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\archive_synthetic_files\\Insulin_file_24.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\archive_synthetic_files\\Insulin_file_25.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\archive_synthetic_files\\Insulin_file_26.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\archive_synthetic_files\\Insulin_file_27.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\archive_synthetic_files\\Insulin_file_28.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\archive_synthetic_files\\Insulin_file_29.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\archive_synthetic_files\\Insulin_file_30.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\archive_synthetic_files\\Insulin_file_31.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\archive_synthetic_files\\Insulin_file_32.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\archive_synthetic_files\\Insulin_file_33.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\archive_synthetic_files\\Insulin_file_34.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\archive_synthetic_files\\Insulin_file_35.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\archive_synthetic_files\\Insulin_file_36.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\archive_synthetic_files\\Insulin_file_37.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\archive_synthetic_files\\Insulin_file_38.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\archive_synthetic_files\\Paracetamol_file_01.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\archive_synthetic_files\\Paracetamol_file_02.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\archive_synthetic_files\\Paracetamol_file_03.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\archive_synthetic_files\\Paracetamol_file_04.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\archive_synthetic_files\\Paracetamol_file_05.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\archive_synthetic_files\\Paracetamol_file_06.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\archive_synthetic_files\\Paracetamol_file_07.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\archive_synthetic_files\\Paracetamol_file_08.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\archive_synthetic_files\\Paracetamol_file_09.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\archive_synthetic_files\\Paracetamol_file_10.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\archive_synthetic_files\\Paracetamol_file_11.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\archive_synthetic_files\\Paracetamol_file_12.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\archive_synthetic_files\\Paracetamol_file_13.txt', 'C:\\Users\\rauna\\projects\\llm_engineering\\My Projects\\Drug Chatbot\\archive_synthetic_files\\Paracetam ...
# Found 38 files in the knowledge base
# Total characters in knowledge base: 176,215

# %%
embeddings = model.encode(texts)

# %%
display(embeddings)
# Out:
# array([[-0.00711119,  0.00059879, -0.02853651, ..., -0.00643677,
#          0.01375426, -0.05614666],
#        [-0.003915  ,  0.00726718, -0.02938702, ...,  0.06177422,
#         -0.01064054, -0.05059917],
#        [ 0.02110526,  0.01502339, -0.08947492, ..., -0.03373051,
#         -0.06424882, -0.03424831],
#        ...,
#        [-0.04182811, -0.00987741, -0.06228681, ...,  0.02273752,
#         -0.0111073 ,  0.08195892],
#        [-0.06024435, -0.05593288,  0.0208234 , ..., -0.01015832,
#         -0.05146672,  0.01851894],
#        [ 0.04206633,  0.00768207,  0.0544171 , ..., -0.01780523,
#         -0.15760142, -0.03699313]], shape=(38, 384), dtype=float32)

# %%
from IPython.display import display

# %%
display(len(texts[0]))
# Out:
# 4617

# %%
display(len(embeddings.tolist()))
# Out:
# 38

# %%
print(f"\n{'='*60}")
print(f"Model: all-MiniLM-L6-v2")
print(f"Embedding dimension: {embeddings.shape[1]}")
print(f"Number of files embedded: {embeddings.shape[0]}")
print(f"{'='*60}\n")
# Out:
# ============================================================
# Model: all-MiniLM-L6-v2
# Embedding dimension: 384
# Number of files embedded: 38
# ============================================================

# %%
for i, (filename, embedding) in enumerate(zip(filenames, embeddings)):
    print(f"File {i+1}: {filename}")
    print(f"Embedding shape: {embedding.shape}")
    print(f"First 10 values: {embedding[:10]}")
    print(f"Embedding norm: {np.linalg.norm(embedding):.4f}\n")
# Out:
# File 1: Insulin_file_20.txt
# Embedding shape: (384,)
# First 10 values: [-0.00711119  0.00059879 -0.02853651  0.06490651 -0.0015744   0.01248091
#   0.13871484  0.00332701 -0.05012881 -0.03233888]
# Embedding norm: 1.0000
#
# File 2: Insulin_file_21.txt
# Embedding shape: (384,)
# First 10 values: [-0.003915    0.00726718 -0.02938702  0.1107794   0.00360281  0.00920939
#   0.16808288  0.02742099 -0.03401552 -0.05972044]
# Embedding norm: 1.0000
#
# File 3: Insulin_file_22.txt
# Embedding shape: (384,)
# First 10 values: [ 0.02110526  0.01502339 -0.08947492  0.01940117  0.04854615  0.03711494
#   0.11314437  0.03297295  0.01939123 -0.0289671 ]
# Embedding norm: 1.0000
#
# File 4: Insulin_file_23.txt
# Embedding shape: (384,)
# First 10 values: [-0.04127152  0.02074593 -0.08176074  0.02375481 -0.03476764 -0.04611976
#   0.09306694  0.04523805 -0.03107712 -0.04497327]
# Embedding norm: 1.0000
#
# File 5: Insulin_file_24.txt
# Embedding shape: (384,)
# First 10 values: [-0.02588456  0.0470881  -0.04057783  0.0383669  -0.00266412 -0.00659507
#   0.10054076  0.05226462 -0.03117378  0.02466566]
# Embedding norm: 1.0000
#
# File 6: Insulin_file_25.txt
# Embedding shape: (384,)
# First 10 values: [-0.00167601  0.02979511 -0.02440462  0.04478759  0.02096018 -0.00333279
#   0.17056635  0.0206602   0.00396711 -0.01690046]
# Embedding norm: 1.0000
#
# File 7: Insulin_file_26.txt
# Embedding shape: (384,)
# First 10 values: [-0.03816307  0.10430936 -0.05130007  0.06723305  0.03000249  0.05868423
#   0.13910829 -0.0195773   0.01588356 -0.03409789]
# Embedding norm: 1.0000
#
# File 8: Insulin_file_27.txt
# Embedding shape: (384,)
# First 10 values: [-0.03552929  0.09466593  0.02701155 -0.00876523  0.00423341 -0.01053015
#   0.04025202 -0.04446586 -0.00973744 -0.11445715]
# Embedding norm: 1.0000
#
# File 9: Insulin_file_28.txt
# Embedding shape: (384,)
# First 10 values: [ 0.01721722 -0.00186782 -0.05908462  0.03313295 -0.01948411 -0.05536576
#   0.17007565  0.011043    0.02591979 -0.07176203]
# Embedding norm: 1.0000
#
# File 10: Insulin_file_29.txt
# Embedding shape: (384,)
# First 10 values: [-0.00624743  0.02429004 -0.07635398  0.03392131 -0.09029437 -0.054775
#   0.14690767  0.04482672 -0.06536756 -0.01417948]
# Embedding norm: 1.0000
#
# File 11: Insulin_file_30.txt
# Embedding shape: (384,)
# First 10 values: [ 0.01947605  0.04915524 -0.06152695  0.0372198   0.03215336 -0.02124164
#   0.09447607  0.04834288 -0.01159137 -0.03006816]
# Embedding norm: 1.0000
#
# File 12: Insulin_file_31.txt
# Embedding shape: (384,)
# First 10 values: [ 0.01789592  0.05657317 -0.0818993   0.05486645  0.01351553 -0.0228149
#   0.14097747  0.00615752 -0.00735246 -0.04864864]
# Embedding norm: 1.0000
#
# File 13: Insulin_file_32.txt
# Embedding shape: (384,)
# First 10 values: [-0.00164381  0.04143475 -0.02599292  0.09396214  0.02023915  0.04153918
#   0.11261237  0.00796906  0.01304659 -0.07357122]
# Embedding norm: 1.0000
#
# File 14: Insulin_file_33.txt
# Embedding shape: (384,)
# First 10 values: [ 0.00998021 -0.00236857 -0.03853651  0.13649303  0.03498672 -0.00858779
#   0.11576524  0.00857257  0.01487404 -0.03858521]
# Embedding norm: 1.0000
#
# File 15: Insulin_file_34.txt
# Embedding shape: (384,)
# First 10 values: [-0.01543891  0.04513541 -0.03871911  0.04155461 -0.00911914  0.00575139
#   0.10084035  0.00742763 -0.02257358 -0.0110169 ]
# Embedding norm: 1.0000
#
# File 16: Insulin_file_35.txt
# Embedding shape: (384,)
# First 10 values: [ 0.00369817 -0.0009565  -0.02477571  0.04077946  0.02469176  0.04855661
#   0.2051599  -0.02028544  0.01273049 -0.02986632]
# Embedding norm: 1.0000
#
# File 17: Insulin_file_36.txt
# Embedding shape: (384,)
# First 10 values: [-0.02444021  0.03095116 -0.08432989  0.02247906  0.07647237  0.09101047
#   0.088417    0.06751615 -0.03640987  0.00833601]
# Embedding norm: 1.0000
#
# File 18: Insulin_file_37.txt
# Embedding shape: (384,)
# First 10 values: [-0.0203063   0.03741434 -0.05464162  0.11590389  0.04101364 -0.00207824
#   0.10932912 -0.03468796 -0.05183783 -0.08131751]
# Embedding norm: 1.0000
#
# File 19: Insulin_file_38.txt
# Embedding shape: (384,)
# First 10 values: [-0.00051512  0.03226906 -0.0718165   0.08532753  0.03343798 -0.01047737
#   0.1143515  -0.03855389 -0.01889178 -0.07870013]
# Embedding norm: 1.0000
#
# File 20: Paracetamol_file_01.txt
# Embedding shape: (384,)
# First 10 values: [-0.03121755  0.00714299 -0.01756535 -0.01441632 -0.06413102  0.00987202
#   0.07674047  0.05445421 -0.07276027 -0.01634938]
# Embedding norm: 1.0000
#
# File 21: Paracetamol_file_02.txt
# Embedding shape: (384,)
# First 10 values: [ 0.01701781 -0.06746283  0.03736177  0.03142466 -0.04130188 -0.03429483
#   0.09132987  0.04524468 -0.0865351  -0.07508684]
# Embedding norm: 1.0000
#
# File 22: Paracetamol_file_03.txt
# Embedding shape: (384,)
# First 10 values: [-0.01052115 -0.02091547 -0.04784062 -0.04737949 -0.00372233  0.03440956
#   0.08521216  0.04077494  0.00743121 -0.03540793]
# Embedding norm: 1.0000
#
# File 23: Paracetamol_file_04.txt
# Embedding shape: (384,)
# First 10 values: [-0.02964021 -0.03555389 -0.02727536 -0.0722476  -0.0288797   0.01453096
#   0.01989439  0.18329667 -0.04918452 -0.01869437]
# Embedding norm: 1.0000
#
# File 24: Paracetamol_file_05.txt
# Embedding shape: (384,)
# First 10 values: [-0.00063839  0.02613029 -0.02853907 -0.02454544 -0.04639028  0.02340324
#   0.06653481  0.1463232  -0.06774189  0.05148474]
# Embedding norm: 1.0000
#
# File 25: Paracetamol_file_06.txt
# Embedding shape: (384,)
# First 10 values: [-0.01746048 -0.02452641  0.00303867 -0.02444177 -0.0642679  -0.02801191
#   0.08832598  0.12094077 -0.09602386 -0.02547782]
# Embedding norm: 1.0000
#
# File 26: Paracetamol_file_07.txt
# Embedding shape: (384,)
# First 10 values: [-0.0341071  -0.00038967 -0.02936004 -0.03461601 -0.0617604   0.01438031
#   0.06110671  0.04267136 -0.02869892 -0.05881553]
# Embedding norm: 1.0000
#
# File 27: Paracetamol_file_08.txt
# Embedding shape: (384,)
# First 10 values: [ 0.00294658  0.02182892 -0.0353038  -0.01143607 -0.00922585  0.02697622
#   0.02057587  0.06009356 -0.00785685 -0.07744421]
# Embedding norm: 1.0000
#
# File 28: Paracetamol_file_09.txt
# Embedding shape: (384,)
# First 10 values: [ 0.06659187 -0.13252549  0.01678927 -0.03147225 -0.09684119 -0.03437183
#   0.14180431  0.04381865 -0.01477772 -0.08020511]
# Embedding norm: 1.0000
#
# File 29: Paracetamol_file_10.txt
# Embedding shape: (384,)
# First 10 values: [-0.01737415 -0.05957669 -0.01331497 -0.00593676 -0.0564637  -0.02394798
#   0.1155531   0.07652777 -0.07641038 -0.043537  ]
# Embedding norm: 1.0000
#
# File 30: Paracetamol_file_11.txt
# Embedding shape: (384,)
# First 10 values: [-0.01273428 -0.05307935 -0.00854492  0.02455389 -0.00469992  0.03042251
#  -0.01648825  0.18296766 -0.05810422  0.00624951]
# Embedding norm: 1.0000
#
# File 31: Paracetamol_file_12.txt
# Embedding shape: (384,)
# First 10 values: [ 0.00024321  0.02686314  0.00490861 -0.0348461  -0.00177047  0.00738053
#   0.05257856  0.09666904 -0.02437534 -0.05606852]
# Embedding norm: 1.0000
#
# File 32: Paracetamol_file_13.txt
# Embedding shape: (384,)
# First 10 values: [ 0.01256188  0.00305499  0.00515027  0.04300848 -0.00119674  0.07044274
#   0.07708739  0.0745377  -0.0103     -0.09505872]
# Embedding norm: 1.0000
#
# File 33: Paracetamol_file_14.txt
# Embedding shape: (384,)
# First 10 values: [ 0.01814336 -0.01273118  0.01070547  0.04598561  0.01157756  0.03003538
#   0.08716361  0.06586152 -0.01295584 -0.01623111]
# Embedding norm: 1.0000
#
# File 34: Paracetamol_file_15.txt
# Embedding shape: (384,)
# First 10 values: [-0.01199865 -0.05245337  0.02975188 -0.01338715 -0.03598224  0.01916992
#   0.02377415  0.06167814 -0.00692653 -0.02669833]
# Embedding norm: 1.0000
#
# File 35: Paracetamol_file_16.txt
# Embedding shape: (384,)
# First 10 values: [-0.00655799 -0.05598213  0.03228336 -0.07195421 -0.06124109  0.04085141
#   0.11314882  0.0232669  -0.01536601 -0.03277649]
# Embedding norm: 1.0000
#
# File 36: Paracetamol_file_17.txt
# Embedding shape: (384,)
# First 10 values: [-0.04182811 -0.00987741 -0.06228681 -0.03571691  0.00903644  0.07921397
#   0.03774701  0.08443514 -0.08331539  0.0001689 ]
# Embedding norm: 1.0000
#
# File 37: Paracetamol_file_18.txt
# Embedding shape: (384,)
# First 10 values: [-0.06024435 -0.05593288  0.0208234   0.01156308  0.00099382  0.00017997
#   0.01681002  0.09085273 -0.1157989  -0.0774271 ]
# Embedding norm: 1.0000
#
# File 38: Paracetamol_file_19.txt
# Embedding shape: (384,)
# First 10 values: [ 0.04206633  0.00768207  0.0544171   0.07746289  0.06589454 -0.08584869
#   0.07748024  0.00868355 -0.02985482 -0.00156443]
# Embedding norm: 1.0000

# %%
def cosine_similarity(vec1, vec2):
    return np.dot(vec1, vec2) / (np.linalg.norm(vec1) * np.linalg.norm(vec2))

# %%
print("Similarity Matrix:")
print("-" * 60)
for i in range(len(filenames)):
    for j in range(len(filenames)):
        sim = cosine_similarity(embeddings[i], embeddings[j])
        print(f"{filenames[i]} vs {filenames[j]}: {sim:.4f}")
    print()
# Out:
# Similarity Matrix:
# ------------------------------------------------------------
# Insulin_file_20.txt vs Insulin_file_20.txt: 1.0000
# Insulin_file_20.txt vs Insulin_file_21.txt: 0.7442
# Insulin_file_20.txt vs Insulin_file_22.txt: 0.4547
# Insulin_file_20.txt vs Insulin_file_23.txt: 0.6250
# Insulin_file_20.txt vs Insulin_file_24.txt: 0.6034
# Insulin_file_20.txt vs Insulin_file_25.txt: 0.7274
# Insulin_file_20.txt vs Insulin_file_26.txt: 0.6356
# Insulin_file_20.txt vs Insulin_file_27.txt: 0.1788
# Insulin_file_20.txt vs Insulin_file_28.txt: 0.6587
# Insulin_file_20.txt vs Insulin_file_29.txt: 0.7044
# Insulin_file_20.txt vs Insulin_file_30.txt: 0.5119
# Insulin_file_20.txt vs Insulin_file_31.txt: 0.7086
# Insulin_file_20.txt vs Insulin_file_32.txt: 0.6714
# Insulin_file_20.txt vs Insulin_file_33.txt: 0.7155
# Insulin_file_20.txt vs Insulin_file_34.txt: 0.6478
# Insulin_file_20.txt vs Insulin_file_35.txt: 0.7177
# Insulin_file_20.txt vs Insulin_file_36.txt: 0.5925
# Insulin_file_20.txt vs Insulin_file_37.txt: 0.5874
# Insulin_file_20.txt vs Insulin_file_38.txt: 0.5154
# Insulin_file_20.txt vs Paracetamol_file_01.txt: 0.4390
# Insulin_file_20.txt vs Paracetamol_file_02.txt: 0.2582
# Insulin_file_20.txt vs Paracetamol_file_03.txt: 0.1892
# Insulin_file_20.txt vs Paracetamol_file_04.txt: 0.1794
# Insulin_file_20.txt vs Paracetamol_file_05.txt: 0.1533
# Insulin_file_20.txt vs Paracetamol_file_06.txt: 0.1224
# Insulin_file_20.txt vs Paracetamol_file_07.txt: 0.1285
# Insulin_file_20.txt vs Paracetamol_file_08.txt: 0.0851
# Insulin_file_20.txt vs Paracetamol_file_09.txt: 0.1863
# Insulin_file_20.txt vs Paracetamol_file_10.txt: 0.2281
# Insulin_file_20.txt vs Paracetamol_file_11.txt: 0.0676
# Insulin_file_20.txt vs Paracetamol_file_12.txt: 0.1957
# Insulin_file_20.txt vs Paracetamol_file_13.txt: 0.2101
# Insulin_file_20.txt vs Paracetamol_file_14.txt: 0.2047
# Insulin_file_20.txt vs Paracetamol_file_15.txt: 0.1226
# Insulin_file_20.txt vs Paracetamol_file_16.txt: 0.2745
# Insulin_file_20.txt vs Paracetamol_file_17.txt: 0.0732
# Insulin_file_20.txt vs Paracetamol_file_18.txt: 0.2155
# Insulin_file_20.txt vs Paracetamol_file_19.txt: 0.1634
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[50], line 5
#       3 for i in range(len(filenames)):
#       4     for j in range(len(filenames)):
# ----> 5         sim = cosine_similarity(embeddings[i], embeddings[j])
#       6         print(f"{filenames[i]} vs {filenames[j]}: {sim:.4f}")
#       7     print()
#
# IndexError: index 38 is out of bounds for axis 0 with size 38

# %%
COLLECTION_NAME = "document_embeddings"  # ChromaDB collection name
DB_PATH = r"C:\Users\rauna\projects\llm_engineering\My Projects\Drug Chatbot\ChromaDB\chroma_db"

# %%
chroma_client = chromadb.PersistentClient(path=DB_PATH)

# %%
collection = chroma_client.get_or_create_collection(
    name=COLLECTION_NAME,
    metadata={"description": "Text file embeddings using all-MiniLM-L6-v2"}
)

# %%
print(collection)

# %%
for file_path in file_paths:
    f1 = [part.split(os.sep)[1] for part in file_path.split('_')[3:-1]]
    # f2 = f1.split(os.sep)[1]
    print(f1)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[94], line 2
#       1 for file_path in file_paths:
# ----> 2     f1 = [part.split(os.sep)[1] for part in file_path.split('_')[3:-1]]
#       3     # f2 = f1.split(os.sep)[1]
#       4     print(f1)
#
# IndexError: list index out of range

# %%
for file_path in file_paths:
    f1 = [os.path.basename(file_path).split('_')[0]]
    # f2 = f1.split(os.sep)[1]
    print( f1)

# %%
print("Adding embeddings to ChromaDB...")
ids = [f"doc_{i}" for i in range(len(filenames))]
metadatas = [{"filename": fn, "person": fp} for fn, fp in zip(filenames, [file_path.split('_')[3:-1][0].split(os.sep)[1]])]
# Out:
# Adding embeddings to ChromaDB...

# %%
def extract_person(path):
    filename = os.path.basename(path)            # Insulin_file_20.txt
    person = filename.split("_file_")[0]         # "Insulin"
    return {"person": person}

# %%
print("Adding embeddings to ChromaDB...")
ids = [f"doc_{i}" for i in range(len(filenames))]
metadatas = [{"filename": fn, **fp} for fn, fp in zip(filenames, person_dict)]
# Out:
# Adding embeddings to ChromaDB...

# %%
person_dict = [extract_person(p) for p in file_paths]

print(person_dict)
# Out:
# [{'person': 'Insulin'}, {'person': 'Insulin'}, {'person': 'Insulin'}, {'person': 'Insulin'}, {'person': 'Insulin'}, {'person': 'Insulin'}, {'person': 'Insulin'}, {'person': 'Insulin'}, {'person': 'Insulin'}, {'person': 'Insulin'}, {'person': 'Insulin'}, {'person': 'Insulin'}, {'person': 'Insulin'}, {'person': 'Insulin'}, {'person': 'Insulin'}, {'person': 'Insulin'}, {'person': 'Insulin'}, {'person': 'Insulin'}, {'person': 'Insulin'}, {'person': 'Paracetamol'}, {'person': 'Paracetamol'}, {'person': 'Paracetamol'}, {'person': 'Paracetamol'}, {'person': 'Paracetamol'}, {'person': 'Paracetamol'}, {'person': 'Paracetamol'}, {'person': 'Paracetamol'}, {'person': 'Paracetamol'}, {'person': 'Paracetamol'}, {'person': 'Paracetamol'}, {'person': 'Paracetamol'}, {'person': 'Paracetamol'}, {'person': 'Paracetamol'}, {'person': 'Paracetamol'}, {'person': 'Paracetamol'}, {'person': 'Paracetamol'}, {'person': 'Paracetamol'}, {'person': 'Paracetamol'}]

# %%
print([file_path.split('_')[3:-1][0].split(os.sep)[1]])
# Out:
# ['Paracetamol']

# %%
print(metadatas)
# Out:
# [{'filename': 'Insulin_file_20.txt', 'person': 'Insulin'}, {'filename': 'Insulin_file_21.txt', 'person': 'Insulin'}, {'filename': 'Insulin_file_22.txt', 'person': 'Insulin'}, {'filename': 'Insulin_file_23.txt', 'person': 'Insulin'}, {'filename': 'Insulin_file_24.txt', 'person': 'Insulin'}, {'filename': 'Insulin_file_25.txt', 'person': 'Insulin'}, {'filename': 'Insulin_file_26.txt', 'person': 'Insulin'}, {'filename': 'Insulin_file_27.txt', 'person': 'Insulin'}, {'filename': 'Insulin_file_28.txt', 'person': 'Insulin'}, {'filename': 'Insulin_file_29.txt', 'person': 'Insulin'}, {'filename': 'Insulin_file_30.txt', 'person': 'Insulin'}, {'filename': 'Insulin_file_31.txt', 'person': 'Insulin'}, {'filename': 'Insulin_file_32.txt', 'person': 'Insulin'}, {'filename': 'Insulin_file_33.txt', 'person': 'Insulin'}, {'filename': 'Insulin_file_34.txt', 'person': 'Insulin'}, {'filename': 'Insulin_file_35.txt', 'person': 'Insulin'}, {'filename': 'Insulin_file_36.txt', 'person': 'Insulin'}, {'filename': 'Insulin_file_37.txt', 'person': 'Insulin'}, {'filename': 'Insulin_file_38.txt', 'person': 'Insulin'}, {'filename': 'Paracetamol_file_01.txt', 'person': 'Paracetamol'}, {'filename': 'Paracetamol_file_02.txt', 'person': 'Paracetamol'}, {'filename': 'Paracetamol_file_03.txt', 'person': 'Paracetamol'}, {'filename': 'Paracetamol_file_04.txt', 'person': 'Paracetamol'}, {'filename': 'Paracetamol_file_05.txt', 'person': 'Paracetamol'}, {'filename': 'Paracetamol_file_06.txt', 'person': 'Paracetamol'}, {'filename': 'Paracetamol_file_07.txt', 'person': 'Paracetamol'}, {'filename': 'Paracetamol_file_08.txt', 'person': 'Paracetamol'}, {'filename': 'Paracetamol_file_09.txt', 'person': 'Paracetamol'}, {'filename': 'Paracetamol_file_10.txt', 'person': 'Paracetamol'}, {'filename': 'Paracetamol_file_11.txt', 'person': 'Paracetamol'}, {'filename': 'Paracetamol_file_12.txt', 'person': 'Paracetamol'}, {'filename': 'Paracetamol_file_13.txt', 'person': 'Paracetamol'}, {'filename': 'Paracetamol_file_14.txt', 'person': 'Paracetamol'}, {'filename': 'Paracetamol_file_15.txt', 'person': 'Paracetamol'}, {'filename': 'Paracetamol_file_16.txt', 'person': 'Paracetamol'}, {'filename': 'Paracetamol_file_17.txt', 'person': 'Paracetamol'}, {'filename': 'Paracetamol_file_18.txt', 'person': 'Paracetamol'}, {'filename': 'Paracetamol_file_19.txt', 'person': 'Paracetamol'}]

# %%
collection.add(
    embeddings=embeddings.tolist(),
    documents=texts,
    metadatas=metadatas,
    ids=ids
)

# %%
display(embeddings.tolist()[0])
display(texts[0])
display(metadatas[0])
display(ids[0])

# %%
query = "who is insulin"

# %%
results = collection.query(
    query_texts=[query],
    n_results=min(5, len(filenames))
)

# %%
print("\nMost similar documents:")
for i, (doc_id, distance, metadata) in enumerate(zip(
    results['ids'][0], 
    results['distances'][0], 
    results['metadatas'][0]
)):
    similarity = 1 - distance  # Convert distance to similarity
    print(f"  {i+1}. {metadata['filename']} (similarity: {similarity:.4f})")

# %%
print("\n" + "="*60)
print("ChromaDB Collection Info:")
print("="*60)
print(f"Collection name: {COLLECTION_NAME}")
print(f"Total documents: {collection.count()}")
print(f"Database path: {DB_PATH}")
print("\nTo query this collection later, use:")
print(f"  collection = chroma_client.get_collection('{COLLECTION_NAME}')")
print(f"  results = collection.query(query_texts=['your query'], n_results=5)")
