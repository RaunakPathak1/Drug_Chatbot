# %%
pip install chromadb
# Out:
# Note: you may need to restart the kernel to use updated packages.
# c:\Users\rauna\projects\llm_engineering\.venv\Scripts\python.exe: No module named pip

# %%
import chromadb

# Create a client (in-memory by default)
client = chromadb.Client()

# %%
collection = client.create_collection(name="my_collection1")

collection.add(
    documents=["This is a document", "This is another document"],
    metadatas=[{"source": "notion"}, {"source": "google-docs"}],
    ids=["id1", "id2"]
)

# Query the collection
results = collection.query(
    query_texts=["document"],
    n_results=2
)

print(results)
# Out:
# C:\Users\rauna\.cache\chroma\onnx_models\all-MiniLM-L6-v2\onnx.tar.gz: 100%|██████████| 79.3M/79.3M [00:21<00:00, 3.92MiB/s]
# {'ids': [['id1', 'id2']], 'embeddings': None, 'documents': [['This is a document', 'This is another document']], 'uris': None, 'included': ['metadatas', 'documents', 'distances'], 'data': None, 'metadatas': [[{'source': 'notion'}, {'source': 'google-docs'}]], 'distances': [[0.3498927056789398, 0.6846550107002258]]}
